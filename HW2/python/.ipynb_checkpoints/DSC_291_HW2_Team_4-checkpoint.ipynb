# %% [markdown]
# ## measuring memory latency

# %% [markdown]
# The purpose of this notebook is to overcome a problem int the notebook `2_measuring_performance_of_memory_hierarchy.ipynb`.
#
# The problem is that the `time()` function is only accurate up to $10^{-7}$ of a second. So any operations that take a shorter time do not register as taking any time.
#
# To overcome the problem we perform many random pokes in sequence and measure the time it takes to complete all of the pokes.
#
# As we ware interested in times shorter than $10^{-7}$ we restrict our attention to the main memory, rather than to files.

# %% [markdown]
# ### Import modules

# %%
# %pylab inline
from numpy import *
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import time
from matplotlib.backends.backend_pdf import PdfPages

from os.path import isfile,isdir
from os import mkdir
import os

# %%
from lib.measureRandomAccess import measureRandomAccess
from lib.PlotTime import PlotTime

# %% [markdown]
# ### setting parameters
# * We test access to elements arrays whose sizes are:
#    * 1MB, 10MB, 100MB, 1000MB (=1GB)
# * Arrays are stored **in memory** or on disk **on disk**

# %% [markdown]
# * We perform 1 million read/write ops  to random locations in the array.
# * We analyze the **distribution** of the latencies.

# %%
n=100 # size of single block (1MB)
m_list=[1,10,100,1000,10000] # size of file in blocks
k=100000;  # number of repeats
L=len(m_list)
print('n=%d, k=%d, m_list='%(n,k),m_list)
# Out:
# n=100, k=100000, m_list= [1, 10, 100, 1000, 10000]

# %% [markdown]
# ### Set working directory
# This script generates large files. We put these files in a separate directory so it is easier to delete them later.

# %%
log_root='./logs'
if not isdir(log_root): mkdir(log_root)
TimeStamp=str(int(time.time()))
log_dir=log_root+'/'+TimeStamp
mkdir(log_dir)
# %cd $log_dir
stat=open('stats.txt','w')

def tee(line):
    print(line)
    stat.write(line+'\n')
# Out:
# /home/ubuntu/workspace/Public-DSC291/notebooks/Section1-Basics/0.MemoryLatency/logs/1587268466/logs/1587270437

# %%
_mean=zeros([2,L])   #0: using disk, 1: using memory
_std=zeros([2,L])
Tmem=[]
TFile=[]

# %%
import numpy as np
from numpy.random import rand
import time

def measureRandomAccessMemBlocks(sz,k=1000,batch=100):
    """Measure the distribution of random accesses in computer memory.

    :param sz: size of memory block.
    :param k: number of times that the experiment is repeated.
    :param batch: The number of locations poked in a single experiment (multiple pokes performed using numpy, rather than python loop)
    :returns: (_mean,std,T):
              _mean = the mean of T
              _std = the std of T
              T = a list the contains the times of all k experiments
    :rtype: tuple

    """
    # Prepare buffer.
    A=np.zeros(sz,dtype=np.int8)
            
    # Read and write k*batch times from/to buffer.
    sum=0; sum2=0
    T=np.zeros(k)
    for i in range(k):
        if (i%100==0): print('\r',i, end=' ')
        loc=np.int32(rand(batch)*sz)
        t=time.time()
        x=A[loc]
        A[loc]=loc
        d=(time.time()-t)/batch
        T[i]=d
        sum += d
        sum2 += d*d
    _mean=sum/k; var=(sum2/k)-_mean**2; _std=np.sqrt(var)
    return (_mean,_std,T)

# %%
m_list=[10000000, 20000000, 30000000, 40000000, 50000000, 60000000, 70000000]
m_legend=['10MB', '20MB', '30MB', '40MB', '50MB', '60MB', '70MB']

# %%
# Out:
# Empty DataFrame
# Columns: [10000000_Mean, 10000000_STD, 20000000_Mean, 20000000_STD, 30000000_Mean, 30000000_STD, 40000000_Mean, 40000000_STD, 50000000_Mean, 50000000_STD, 60000000_Mean, 60000000_STD, 70000000_Mean, 70000000_STD]
# Index: []

# %%
# Create a pandas dataframe to store the results. 
import pandas as pd

col_names = [] # Format pandas column names 
col_names.append('Time')
for i in m_list: 
    col_names.append(str(i) + '_Mean')
    col_names.append(str(i) + '_STD')
#df = pd.DataFrame(columns=col_names) 

#print(df)

#print(df[:5])

data = []
# Add a timer and a loop for the code below to run a trial of random_pokes() once per minute.
import time

num_trials = 0

while num_trials < 12:   # number of trials to run of time length x in time.sleep(x)
    localtime = time.localtime()
    result = time.strftime("%I:%M:%S %p", localtime)
    print(result, end="", flush=True)
    print("\r", end="", flush=True)
  

    Random_pokes=[]

    L=len(m_list)
    _mean=zeros([L])   #0: using disk, 1: using memory
    _std=zeros([L])
    TMem=[0]*L

    data_row = [result]
    for m_i in range(L):
        m=m_list[m_i]
        print('Memory array %d Bytes'%m)
        out = measureRandomAccessMemBlocks(m,k=1000,batch=1000)
        (_mean[m_i],_std[m_i],TMem[m_i]) = out
        TMem[m_i].sort()
        tee('\rMemory pokes _mean='+str(_mean[m_i])+', Memory _std='+str(_std[m_i]))

        Random_pokes.append({'m_i':m_i,
                            'm':m,
                            'memory__mean': _mean[m_i],
                            'memory__std': _std[m_i],
                            'memory_largest': TMem[m_i][-100:],
                    })

        data_row.append(str(_mean[m_i]))
        data_row.append(str(_std[m_i]))
       
    #print(data_row)
    #row_df = pd.DataFrame(data_row, columns=col_names).T
    #df = df.concat(row_df)
    
        
    #row_df = pd.DataFrame([data_row])
    #df = pd.concat([pd.Series(row_df), df])
    #df.append(pd.Series(np.array(data_row)), ignore_index=True)
    data.append(data_row)
    time.sleep(5)   # sleep function is in seconds 
    num_trials += 1
# Out:
# Memory array 10000000 Bytes
# Memory pokes _mean=1.0222625732421867e-07, Memory _std=1.2044756640363614e-07
# Memory array 20000000 Bytes
# Memory pokes _mean=1.0834765434265142e-07, Memory _std=2.4384234258112973e-07
# Memory array 30000000 Bytes
# Memory pokes _mean=1.0554814338684084e-07, Memory _std=2.2616435494659714e-07
# Memory array 40000000 Bytes
# Memory pokes _mean=1.2861227989196785e-07, Memory _std=2.6155479915505637e-07
# Memory array 50000000 Bytes
# Memory pokes _mean=1.4396977424621587e-07, Memory _std=2.899839137538155e-07
# Memory array 60000000 Bytes
# Memory pokes _mean=1.506292819976809e-07, Memory _std=3.208843558097823e-07
# Memory array 70000000 Bytes
# Memory pokes _mean=8.254003524780285e-08, Memory _std=1.823982951916671e-07
# Memory array 10000000 Bytes
# Memory pokes _mean=1.2635231018066409e-07, Memory _std=2.881726649098372e-07
# Memory array 20000000 Bytes
# Memory pokes _mean=8.271074295043933e-08, Memory _std=1.691535660481203e-07
# Memory array 30000000 Bytes
# Memory pokes _mean=1.5047717094421382e-07, Memory _std=2.49847416351915e-07
# Memory array 40000000 Bytes
# Memory pokes _mean=2.0567083358764668e-07, Memory _std=6.405323208484186e-07
# Memory array 50000000 Bytes
# Memory pokes _mean=6.896162033081059e-08, Memory _std=1.59146800984643e-07
# Memory array 60000000 Bytes
# Memory pokes _mean=7.455873489379884e-08, Memory _std=1.6581684467127125e-07
# Memory array 70000000 Bytes
# Memory pokes _mean=7.799172401428221e-08, Memory _std=1.7618283739757794e-07
# Memory array 10000000 Bytes
# Memory pokes _mean=8.641624450683599e-08, Memory _std=1.5007144957328369e-07
# Memory array 20000000 Bytes
# Memory pokes _mean=8.665800094604475e-08, Memory _std=1.9140052466289466e-07
# Memory array 30000000 Bytes
# Memory pokes _mean=9.270715713500976e-08, Memory _std=4.1195373121279724e-07
# Memory array 40000000 Bytes
# Memory pokes _mean=1.706948280334474e-07, Memory _std=9.291242135687357e-07
# Memory array 50000000 Bytes
# Memory pokes _mean=7.791256904602039e-08, Memory _std=2.0044383132315637e-07
# Memory array 60000000 Bytes
# Memory pokes _mean=8.076906204223616e-08, Memory _std=1.8657763866396155e-07
# Memory array 70000000 Bytes
# Memory pokes _mean=8.517956733703625e-08, Memory _std=2.011582113419593e-07
# Memory array 10000000 Bytes
# Memory pokes _mean=5.931448936462395e-08, Memory _std=6.924682992116028e-08
# Memory array 20000000 Bytes
# Memory pokes _mean=7.815575599670409e-08, Memory _std=2.846780420178266e-07
# Memory array 30000000 Bytes
# Memory pokes _mean=6.928968429565439e-08, Memory _std=9.8985672037268e-08
# Memory array 40000000 Bytes
# Memory pokes _mean=9.892106056213382e-08, Memory _std=2.2654918937244176e-07
# Memory array 50000000 Bytes
# Memory pokes _mean=1.1072444915771488e-07, Memory _std=2.5314556262596514e-07
# Memory array 60000000 Bytes
# Memory pokes _mean=7.775878906249994e-08, Memory _std=2.0783320238815957e-07
# Memory array 70000000 Bytes
# Memory pokes _mean=7.820940017700177e-08, Memory _std=1.8260460215605102e-07
# Memory array 10000000 Bytes
# Memory pokes _mean=5.642127990722661e-08, Memory _std=1.1387215384680351e-07
# Memory array 20000000 Bytes
# Memory pokes _mean=5.144071578979504e-08, Memory _std=6.347687316516741e-08
# Memory array 30000000 Bytes
# Memory pokes _mean=6.072998046874996e-08, Memory _std=1.0068437924950753e-07
# Memory array 40000000 Bytes
# Memory pokes _mean=8.59215259552003e-08, Memory _std=1.9795031062943212e-07
# Memory array 50000000 Bytes
# Memory pokes _mean=8.084654808044441e-08, Memory _std=2.225012750279083e-07
# Memory array 60000000 Bytes
# Memory pokes _mean=7.791805267333978e-08, Memory _std=1.728785862689593e-07
# Memory array 70000000 Bytes
# Memory pokes _mean=8.189797401428217e-08, Memory _std=1.8514832745662102e-07
# Memory array 10000000 Bytes
# Memory pokes _mean=7.218790054321288e-08, Memory _std=1.3310282115162e-07
# Memory array 20000000 Bytes
# Memory pokes _mean=9.421992301940924e-08, Memory _std=3.8012709926896786e-07
# Memory array 30000000 Bytes
# Memory pokes _mean=9.601926803588873e-08, Memory _std=2.2156183001513153e-07
# Memory array 40000000 Bytes
# Memory pokes _mean=1.2402391433715832e-07, Memory _std=3.36045330642436e-07
# Memory array 50000000 Bytes
# Memory pokes _mean=1.1084175109863294e-07, Memory _std=3.5805927758516714e-07
# Memory array 60000000 Bytes
# Memory pokes _mean=8.117842674255373e-08, Memory _std=1.8505974176845723e-07
# Memory array 70000000 Bytes
# Memory pokes _mean=8.289551734924318e-08, Memory _std=1.8876355138452815e-07
# Memory array 10000000 Bytes
# Memory pokes _mean=6.267285346984864e-08, Memory _std=1.3511806293139112e-07
# Memory array 20000000 Bytes
# Memory pokes _mean=1.0456323623657231e-07, Memory _std=2.7798324304099334e-07
# Memory array 30000000 Bytes
# Memory pokes _mean=9.246850013732911e-08, Memory _std=2.5244120515348516e-07
# Memory array 40000000 Bytes
# Memory pokes _mean=2.043519020080568e-07, Memory _std=7.510741606420453e-07
# Memory array 50000000 Bytes
# Memory pokes _mean=7.094144821166989e-08, Memory _std=1.5608302940459578e-07
# Memory array 60000000 Bytes
# Memory pokes _mean=7.677626609802234e-08, Memory _std=1.820489852413377e-07
# Memory array 70000000 Bytes
# Memory pokes _mean=8.065605163574218e-08, Memory _std=1.8144543145752352e-07
# Memory array 10000000 Bytes
# Memory pokes _mean=1.4296436309814462e-07, Memory _std=8.167055549760293e-07
# Memory array 20000000 Bytes
# Memory pokes _mean=1.5461015701293916e-07, Memory _std=6.617471289564243e-07
# Memory array 30000000 Bytes
# Memory pokes _mean=1.240797042846679e-07, Memory _std=3.4669137838666695e-07
# Memory array 40000000 Bytes
# Memory pokes _mean=7.522392272949206e-08, Memory _std=1.721621886753262e-07
# Memory array 50000000 Bytes
# Memory pokes _mean=8.45556259155275e-08, Memory _std=2.2381313762114338e-07
# Memory array 60000000 Bytes
# Memory pokes _mean=8.493804931640637e-08, Memory _std=1.9129609306114878e-07
# Memory array 70000000 Bytes
# Memory pokes _mean=9.022355079650873e-08, Memory _std=2.1283862681821465e-07
# Memory array 10000000 Bytes
# Memory pokes _mean=7.804775238037102e-08, Memory _std=2.6127537301097926e-07
# Memory array 20000000 Bytes
# Memory pokes _mean=7.595992088317866e-08, Memory _std=2.682207154378248e-07
# Memory array 30000000 Bytes
# Memory pokes _mean=8.3559274673462e-08, Memory _std=3.1175229510495774e-07
# Memory array 40000000 Bytes
# Memory pokes _mean=9.321761131286631e-08, Memory _std=3.987182572187887e-07
# Memory array 50000000 Bytes
# Memory pokes _mean=7.410740852355963e-08, Memory _std=1.6756533954927288e-07
# Memory array 60000000 Bytes
# Memory pokes _mean=8.600473403930665e-08, Memory _std=2.1142578184740244e-07
# Memory array 70000000 Bytes
# Memory pokes _mean=8.963561058044425e-08, Memory _std=2.0788937628566038e-07
# Memory array 10000000 Bytes
# Memory pokes _mean=5.963134765625009e-08, Memory _std=1.0710332688861657e-07
# Memory array 20000000 Bytes
# Memory pokes _mean=8.891510963439927e-08, Memory _std=3.514092906850299e-07
# Memory array 30000000 Bytes
# Memory pokes _mean=6.898427009582515e-08, Memory _std=1.3018998242605595e-07
# Memory array 40000000 Bytes
# Memory pokes _mean=9.897971153259261e-08, Memory _std=2.7959522267653514e-07
# Memory array 50000000 Bytes
# Memory pokes _mean=9.706306457519515e-08, Memory _std=5.00211946376614e-07
# Memory array 60000000 Bytes
# Memory pokes _mean=8.970379829406742e-08, Memory _std=2.895960133814809e-07
# Memory array 70000000 Bytes
# Memory pokes _mean=8.563017845153819e-08, Memory _std=1.9392572714434207e-07
# Memory array 10000000 Bytes
# Memory pokes _mean=5.028724670410152e-08, Memory _std=1.0546062222011619e-07
# Memory array 20000000 Bytes
# Memory pokes _mean=5.379128456115722e-08, Memory _std=1.229920485144441e-07
# Memory array 30000000 Bytes
# Memory pokes _mean=5.4169654846191457e-08, Memory _std=1.1557640587335659e-07
# Memory array 40000000 Bytes
# Memory pokes _mean=8.156371116638197e-08, Memory _std=2.1415798050972925e-07
# Memory array 50000000 Bytes
# Memory pokes _mean=8.76395702362061e-08, Memory _std=2.5107584341682947e-07
# Memory array 60000000 Bytes
# Memory pokes _mean=1.0181760787963874e-07, Memory _std=2.528513333117112e-07
# Memory array 70000000 Bytes
# Memory pokes _mean=7.999253273010267e-08, Memory _std=1.7825665225083834e-07
# Memory array 10000000 Bytes
# Memory pokes _mean=4.82232570648194e-08, Memory _std=6.487432442007508e-08
# Memory array 20000000 Bytes
# Memory pokes _mean=4.6914100646972697e-08, Memory _std=3.560431816996332e-08
# Memory array 30000000 Bytes
# Memory pokes _mean=5.610299110412598e-08, Memory _std=8.677630761479107e-08
# Memory array 40000000 Bytes
# Memory pokes _mean=9.239745140075697e-08, Memory _std=4.571323079085424e-07
# Memory array 50000000 Bytes
# Memory pokes _mean=8.397269248962409e-08, Memory _std=2.1461121495822704e-07
# Memory array 60000000 Bytes
# Memory pokes _mean=9.635877609252929e-08, Memory _std=2.609540812340287e-07
# Memory array 70000000 Bytes
# Memory pokes _mean=1.0367059707641615e-07, Memory _std=3.875532919909224e-07

# %%
print(data[:2])
# Out:
# [['12:02:11 AM', '1.0222625732421867e-07', '1.2044756640363614e-07', '1.0834765434265142e-07', '2.4384234258112973e-07', '1.0554814338684084e-07', '2.2616435494659714e-07', '1.2861227989196785e-07', '2.6155479915505637e-07', '1.4396977424621587e-07', '2.899839137538155e-07', '1.506292819976809e-07', '3.208843558097823e-07', '8.254003524780285e-08', '1.823982951916671e-07'], ['12:02:18 AM', '1.2635231018066409e-07', '2.881726649098372e-07', '8.271074295043933e-08', '1.691535660481203e-07', '1.5047717094421382e-07', '2.49847416351915e-07', '2.0567083358764668e-07', '6.405323208484186e-07', '6.896162033081059e-08', '1.59146800984643e-07', '7.455873489379884e-08', '1.6581684467127125e-07', '7.799172401428221e-08', '1.7618283739757794e-07']]

# %%
df = pd.DataFrame(data, columns=col_names)
print(df)
# Out:
#            Time           10000000_Mean            10000000_STD  \
# 0   12:02:11 AM  1.0222625732421867e-07  1.2044756640363614e-07
# 1   12:02:18 AM  1.2635231018066409e-07   2.881726649098372e-07
# 2   12:02:24 AM   8.641624450683599e-08  1.5007144957328369e-07
# 3   12:02:30 AM   5.931448936462395e-08   6.924682992116028e-08
# 4   12:02:36 AM   5.642127990722661e-08  1.1387215384680351e-07
# 5   12:02:42 AM   7.218790054321288e-08     1.3310282115162e-07
# 6   12:02:48 AM   6.267285346984864e-08  1.3511806293139112e-07
# 7   12:02:54 AM  1.4296436309814462e-07   8.167055549760293e-07
# 8   12:03:00 AM   7.804775238037102e-08  2.6127537301097926e-07
# 9   12:03:06 AM   5.963134765625009e-08  1.0710332688861657e-07
# 10  12:03:12 AM   5.028724670410152e-08  1.0546062222011619e-07
# 11  12:03:18 AM    4.82232570648194e-08   6.487432442007508e-08
#
#              20000000_Mean            20000000_STD           30000000_Mean  \
# 0   1.0834765434265142e-07  2.4384234258112973e-07  1.0554814338684084e-07
# 1    8.271074295043933e-08   1.691535660481203e-07  1.5047717094421382e-07
# 2    8.665800094604475e-08  1.9140052466289466e-07   9.270715713500976e-08
# 3    7.815575599670409e-08   2.846780420178266e-07   6.928968429565439e-08
# 4    5.144071578979504e-08   6.347687316516741e-08   6.072998046874996e-08
# 5    9.421992301940924e-08  3.8012709926896786e-07   9.601926803588873e-08
# 6   1.0456323623657231e-07  2.7798324304099334e-07   9.246850013732911e-08
# 7   1.5461015701293916e-07   6.617471289564243e-07   1.240797042846679e-07
# 8    7.595992088317866e-08   2.682207154378248e-07     8.3559274673462e-08
# 9    8.891510963439927e-08   3.514092906850299e-07   6.898427009582515e-08
# 10   5.379128456115722e-08   1.229920485144441e-07  5.4169654846191457e-08
# 11  4.6914100646972697e-08   3.560431816996332e-08   5.610299110412598e-08
#
#               30000000_STD           40000000_Mean            40000000_STD  \
# 0   2.2616435494659714e-07  1.2861227989196785e-07  2.6155479915505637e-07
# 1     2.49847416351915e-07  2.0567083358764668e-07   6.405323208484186e-07
# 2   4.1195373121279724e-07   1.706948280334474e-07   9.291242135687357e-07
# 3      9.8985672037268e-08   9.892106056213382e-08  2.2654918937244176e-07
# 4   1.0068437924950753e-07    8.59215259552003e-08  1.9795031062943212e-07
# 5   2.2156183001513153e-07  1.2402391433715832e-07    3.36045330642436e-07
# 6   2.5244120515348516e-07   2.043519020080568e-07   7.510741606420453e-07
# 7   3.4669137838666695e-07   7.522392272949206e-08   1.721621886753262e-07
# 8   3.1175229510495774e-07   9.321761131286631e-08   3.987182572187887e-07
# 9   1.3018998242605595e-07   9.897971153259261e-08  2.7959522267653514e-07
# 10  1.1557640587335659e-07   8.156371116638197e-08  2.1415798050972925e-07
# 11   8.677630761479107e-08   9.239745140075697e-08   4.571323079085424e-07
#
#              50000000_Mean            50000000_STD           60000000_Mean  \
# 0   1.4396977424621587e-07   2.899839137538155e-07   1.506292819976809e-07
# 1    6.896162033081059e-08    1.59146800984643e-07   7.455873489379884e-08
# 2    7.791256904602039e-08  2.0044383132315637e-07   8.076906204223616e-08
# 3   1.1072444915771488e-07  2.5314556262596514e-07   7.775878906249994e-08
# 4    8.084654808044441e-08   2.225012750279083e-07   7.791805267333978e-08
# 5   1.1084175109863294e-07  3.5805927758516714e-07   8.117842674255373e-08
# 6    7.094144821166989e-08  1.5608302940459578e-07   7.677626609802234e-08
# 7     8.45556259155275e-08  2.2381313762114338e-07   8.493804931640637e-08
# 8    7.410740852355963e-08  1.6756533954927288e-07   8.600473403930665e-08
# 9    9.706306457519515e-08    5.00211946376614e-07   8.970379829406742e-08
# 10    8.76395702362061e-08  2.5107584341682947e-07  1.0181760787963874e-07
# 11   8.397269248962409e-08  2.1461121495822704e-07   9.635877609252929e-08
#
#               60000000_STD           70000000_Mean            70000000_STD
# 0    3.208843558097823e-07   8.254003524780285e-08   1.823982951916671e-07
# 1   1.6581684467127125e-07   7.799172401428221e-08  1.7618283739757794e-07
# 2   1.8657763866396155e-07   8.517956733703625e-08   2.011582113419593e-07
# 3   2.0783320238815957e-07   7.820940017700177e-08  1.8260460215605102e-07
# 4    1.728785862689593e-07   8.189797401428217e-08  1.8514832745662102e-07
# 5   1.8505974176845723e-07   8.289551734924318e-08  1.8876355138452815e-07
# 6    1.820489852413377e-07   8.065605163574218e-08  1.8144543145752352e-07
# 7   1.9129609306114878e-07   9.022355079650873e-08  2.1283862681821465e-07
# 8   2.1142578184740244e-07   8.963561058044425e-08  2.0788937628566038e-07
# 9    2.895960133814809e-07   8.563017845153819e-08  1.9392572714434207e-07
# 10   2.528513333117112e-07   7.999253273010267e-08  1.7825665225083834e-07
# 11   2.609540812340287e-07  1.0367059707641615e-07   3.875532919909224e-07

# %% [markdown]
# ### Characterize random access to storage

# %%
pp = PdfPages('MemoryBlockFigure.pdf')
figure(figsize=(6,4))

Colors='bgrcmyk'  # The colors for the plot
LineStyles=['-']

fig = matplotlib.pyplot.gcf()
fig.set_size_inches(18.5,10.5)

for m_i in range(len(m_list)):
    Color=Colors[m_i % len(Colors)]
    PlotTime(TMem[m_i],_mean[m_i],_std[m_i],\
             Color=Color,LS='-',Legend=m_legend[m_i],\
             m_i=m_i)

grid()
legend(fontsize=18)
xlabel('delay (sec)',fontsize=18)
ylabel('1-CDF',fontsize=18)
tick_params(axis='both', which='major', labelsize=16)
tick_params(axis='both', which='minor', labelsize=12)
pp.savefig()
pp.close()

# %% [markdown]
# ### Conclusions
#
# We see that for this laptop (an apple powerbook) the latency of random pokes is close to $10^{-8}$ for blocks of size up to 1 MB. Beyond that, for sizes of 10MB, 100MB and 1GB, the delay is significantly larger.
#
# This makes sense because the size of the L3 cache in this machine is about 6MB.

# %%
Saturday April 18, 2020 9:27:27pm
